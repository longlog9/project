# %%
import os        
import sys
import pandas as pd
import matplotlib.pyplot as plt

import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener

# %%
consumer_key =''
consumer_secret = ''
auth = tweepy.OAuthHandler(consumer_key=consumer_key, consumer_secret=consumer_secret)
api = tweepy.API(auth)

access_token = ''
access_token_secret = ''

# %%
# 1. 인증요청(1차) : 개인 앱 정보 
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)


# 2. access 토큰 요청(2차) - 인증요청 참조변수 이용
auth.set_access_token(access_token, access_token_secret)

# 3. twitter API 생성  
api = tweepy.API(auth)

# %%
keyword = "맥주";     # 자신이 검색하고 싶은 키워드 입력 
search = [] # 크롤링 결과 저장할 변수   

cnt = 1
while(cnt <= 2):   # 10page 대상으로 크롤링
   tweets = api.search(keyword)
   for tweet in tweets:
       search.append(tweet)
   cnt += 2

print(len(search)) # 문서 길이 
print(search[0]) # 첫번째 text 보기
# Out:
# 14
# Status(_api=<tweepy.api.API object at 0x00000222870D9DD8>, _json={'created_at': 'Wed Jan 02 04:57:33 +0000 2019', 'id': 1080327211352113153, 'id_str': '1080327211352113153', 'text': 'RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크림+흑맥주\n복숭아폴라포+복숭아워터젤리+한라산\n초록매실+한라산+각얼음\n보드카+오렌지주스+자몽주스\n맥주+더치커피\n보드카+라임주스+설탕\n문배주+토닉워터+레몬즙\n문배주+사이다+각…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'VI1N4', 'name': '🐅', 'id': 719216874634891265, 'id_str': '719216874634891265', 'indices': [3, 9]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 500943846, 'id_str': '500943846', 'name': 'bebe.K', 'screen_name': 'JJM_cbb', 'location': '', 'description': '죵대가 천지를 창조했다고 해도 믿겠습니다.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 35, 'friends_count': 997, 'listed_count': 0, 'created_at': 'Thu Feb 23 16:43:30 +0000 2012', 'favourites_count': 10578, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 44124, 'lang': 'ko', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1061640613899075584/46t2_bmX_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1061640613899075584/46t2_bmX_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/500943846/1497703587', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue Jan 01 16:34:12 +0000 2019', 'id': 1080140141451071488, 'id_str': '1080140141451071488', 'text': '한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크림+흑맥주\n복숭아폴라포+복숭아워터젤리+한라산\n초록매실+한라산+각얼음\n보드카+오렌지주스+자몽주스\n맥주+더치커피\n보드카+라임주스+설탕\n문배주+토닉워터+… https://t.co/RUDWsAndCl', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/RUDWsAndCl', 'expanded_url': 'https://twitter.com/i/web/status/1080140141451071488', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 719216874634891265, 'id_str': '719216874634891265', 'name': '🐅', 'screen_name': 'VI1N4', 'location': "n'abandonnez pas", 'description': '🌹 @Nu_Ewige', 'url': 'https://t.co/keZnqKv5wu', 'entities': {'url': {'urls': [{'url': 'https://t.co/keZnqKv5wu', 'expanded_url': 'https://goo.gl/pm8DFf', 'display_url': 'goo.gl/pm8DFf', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 108, 'friends_count': 172, 'listed_count': 2, 'created_at': 'Sun Apr 10 17:34:00 +0000 2016', 'favourites_count': 2479, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 70501, 'lang': 'ko', 'contributors_ena ...

# %% [markdown]
# 같은 내용이 반복되는 문제 발생...

# %%
data= {}
i=0

for tweet in search:
    data["text"] = tweet.text 
    print(i,":",data)
    i += 1

# %% [markdown]
# 일단 텍스트 문서로 저장

# %%
f= open("C:/Users/Administrator/Desktop/proj3/BEER.txt",mode="w",encoding='utf-8')
data={}

for tweet in search:
    data["text"] = tweet.text
    f.write(data["text"]+"\n")
    
f.close()

# %% [markdown]
# 새로운 방법 시도

# %%
consumer_key =''
consumer_secret = ''
auth = tweepy.OAuthHandler(consumer_key=consumer_key, consumer_secret=consumer_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

atoken = ''
asecret = ''


results = []
for tweet in tweepy.Cursor(api.search, q='맥주',since='2018-12-11', count=100).items():
    results.append(tweet)
    
print(len(results))
# Out:
# 48716

# %%
def process_results(results):
    id_list = [tweet.id for tweet in results]
    data_set = pd.DataFrame(id_list, columns=["id"])

    # Processing Tweet Data

    data_set["text"] = [tweet.text for tweet in results]
    data_set["created_at"] = [tweet.created_at for tweet in results]
    data_set["retweet_count"] = [tweet.retweet_count for tweet in results]
    data_set["favorite_count"] = [tweet.favorite_count for tweet in results]
    data_set["source"] = [tweet.source for tweet in results]

    # Processing User Data
    data_set["user_id"] = [tweet.author.id for tweet in results]
    data_set["user_screen_name"] = [tweet.author.screen_name for tweet in results]
    data_set["user_name"] = [tweet.author.name for tweet in results]
    data_set["user_created_at"] = [tweet.author.created_at for tweet in results]
    data_set["user_description"] = [tweet.author.description for tweet in results]
    data_set["user_followers_count"] = [tweet.author.followers_count for tweet in results]
    data_set["user_friends_count"] = [tweet.author.friends_count for tweet in results]
    data_set["user_location"] = [tweet.author.location for tweet in results]

    return data_set
data_set = process_results(results)
data_set
# Out:
#                         id                                               text  \
# 0      1080350472488214528  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 1      1080350451797712899  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 2      1080350412480307201  @sth_else_plz 술 좋아하지. 그것도 환장 할 정도로. 공부 한다는 놈이 ...
# 3      1080350389092794370  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 4      1080350383749324800  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 5      1080350372881788928  @Lowell_coups 한국판 맥주? ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 비유 뭔데 찰떡같아...
# 6      1080350350341599237  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 7      1080350341214785536  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 8      1080350322059431937  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 9      1080350300530192384  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 10     1080350298592309248  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 11     1080350278480584704  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 12     1080350276484132864  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 13     1080350242531229697  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 14     1080350168430436352  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 15     1080350126600708096  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 16     1080350094170370049  [흑맥주식빵 만들기 by 미코유] 흑맥주식빵 만들기 by 미코유흑맥주를 넣어서 향과...
# 17     1080350092756840448  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 18     1080350087589449728  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 19     1080350073249099776  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 20     1080350072741584896  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 21     1080350062754975744      @Chure_arashi 엄,,,, 맥주 한 3캔마시면 배 차던데요,,,,,(눈치
# 22     1080350022967865344  RT @duworld_0704: 맥주 CF🍺\nhttps://t.co/dbMTPBy...
# 23     1080350007088242689  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 24     1080349983604264960                                  @0d0rr 맥주 캔 들어가능가
# 25     1080349972443230208  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 26     1080349965728153601  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 27     1080349923722162178  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 28     1080349919469137920  RT @VI1N4: 한라산+토닉워터+레몬즙\n홍차보드카+우유+흑설탕\n바닐라아이스크...
# 48692 2018-12-23 06:41:28              0               1  Twitter for Android
# 48693 2018-12-23 06:36:28            176               0   Twitter for iPhone
# 48694 2018-12-23 06:32:34              0               1   Twitter for iPhone
# 48695 2018-12-23 06:32:01            368               0  Twitter for Android
# 48696 2018-12-23 06:30:56              0               0  Twitter for Android
# 48697 2018-12-23 06:30:54              0               3  Twitter for Android
# 48698 2018-12-23 06:30:14              0               5  Twitter for Android
# 48699 2018-12-23 06:29:59              0               1  Twitter for Android
# 48700 2018-12-23 06:29:47              0               0  Twitter for Android
# 48701 2018-12-23 06:29:11              0               2  Twitter for Android
# 48702 2018-12-23 06:28:58              0               0   Twitter for iPhone
# 48703 2018-12-23 06:26:40              0               2   Twitter for iPhone
# 48704 2018-12-23 06:25:37            500               0  Twitter for Android
# 48705 2018-12-23 06:25:25          12985               0   Twitter for iPhone
# 48706 2018-12-23 06:23:38             36               0  Twitter for Android
# 48707 2018-12-23 06:22:40            967               0   Twitter for iPhone
# 48708 2018-12-23 06:22:38              0               0   Twitter for iPhone
# 48709 2018-12-23 06:19:11              0               3   Twitter for iPhone
# 48710 2018-12-23 06:17:41              0               2         Twitter Lite
# 48711 2018-12-23 06:16:19            163               0   Twitter for iPhone
# 48712 2018-12-23 06:16:18              0               2   Twitter for iPhone
# 48713 2018-12-23 06:10:25              0               1  Twitter for Android
# 48714 2018-12-23 06:10:19              0               2  Twitter for Android
# 48715 2018-12-23 06:10:12            368               0   Twitter for iPhone
#
#                    user_id user_screen_name  \
# 0      1072107662471380992         koisel79
# 1       853241754576855041         Rain2Lia
# 2      1075251436877885441    ___73Gangster
# 3      1080001528943919105       KPaka_1204
# 4      1006166134825992192        Ben_LB_BC
# 5      1079947989802602497      WZ_11_22_JH
# 6       784774261642661888  GReEn_aS_cAn_Be
# 7               2852827842        flowerhrr
# 8       746232542529937408         _hanye25
# 9      1002693323172167680         ellabue5
# 10               927041065     va1ta___tava
# 11      826403574208794624          M00NT4N
# 12      998230237069520896        1984_7_42
# 13     1030783332680777729      guri2guri2_
# 14      888221453820190721      spider_0323
# 15               359253982          Q_BANNH
# 16               421624589   sunyoungmoon91
# 17      947457836870549504       Popduck219
# 18              2963555231         rosi9420
# 19               578714830  Bearjellybasser
# 20      936537712894525441      bluemoon309
# 21      912315624063250432          ze_ren_
# 22              1630630807       fibilui916
# 23               250408636          Ani1059
# 24     1073067485702676481  VVclpyn2suDE5tB
# 25      949800946606907393    DangDangyee84
# 26              4246318039       12_easyone
# 27      728770502714494976          0422_KM
# 28     1017929419388645376      aka21418707
# 29     1012926094838648832      JinLuminous
# ...                    ...              ...
# 48686  1073926675421835264       w1th3r____
# 48687   941477928436514816          kdzzang
# 48688  1029387808979341312      ehdekqk1234
# 48689           4709032393         tianfu__
# 48690           2375446494        Liko_1107
# 48691   982838082666835968       skymoon493
# 48692   923923408278061063   luv_BTS_130613
# 48693           4892785872         daluvwon
# 48694  1027223382029258752           MpkLsy
# 48693                                두둘이서 2016-02-11 13:51:34
# 48694                                 서 녘 2018-08-08 16:01:53
# 48695                                내이비요 2011-02-10 10:41:45
# 48696                 [무멘팔](주)감자연맹 소속☆하랑☆ 2018-11-05 09:38:01
# 48697                                  무룩 2016-09-25 15:48:50
# 48698                              (웰시)코기 2018-04-24 03:17:55
# 48699                  사이다 💙연애서큘레이션 영상 모집 2018-11-27 08:43:42
# 48700                               감자테러범 2018-09-24 05:52:28
# 48701                         요하네진짜데려오고싶어 2016-01-09 09:41:19
# 48702                                 🌱가치 2018-11-20 17:56:12
# 48703                          💜조지 M. 바벨😎 2016-02-21 13:03:16
# 48704                                   뿅 2018-10-05 15:44:58
# 48705                    쓰앵님우리예서설의대보내야합니다 2016-03-05 16:53:12
# 48706                                ㅊㅑ 퐁 2018-11-12 01:39:32
# 48707                                  챠임 2018-07-12 01:57:57
# 48708                            🏆우승팀 팬🥇줌 2018-02-18 14:21:41
# 48709                                  우야 2010-11-06 09:18:51
# 48710                              mayhem 2017-01-02 12:18:48
# 48711                                   뽀 2016-09-26 10:13:35
# 48712                                  루디 2018-11-16 17:06:36
# 48713                            💊Aspirin 2016-10-12 11:19:58
# 48714                               ❃가나슈❃ 2018-11-03 06:59:21
# 48715                        첫13 막14 두주니즈 2013-02-08 02:40:13
#
#                                         user_description  \
# 0                              본진 한지상/프랑켄\n늦덕이라 슬픈 1인...
# 1      FUB FREE (๑¯∇¯๑)/🍁MapleStory2🍁(본진!)/소녀전선/앙스타/스...
# 2                                     한껏 불태울 나이는 한참 지났지.
# 3                  ✨ ғᴀʟʟ ɪɴ ᴊɪɴ , 170726~4ᴇᴠ ✨ 언괄🚫블언블🙏🏻
# 4      20⬇️/무멘팔 구독으로 간주/블랙캣/#벤의_썰갈피/멘션스루, 언팔 고의❌/FUB ...
# 5      https://t.co/jVlrmFK72i / 헤더 : @shell051234 / ...
# 6      레즈구독러 /재밌는얘기 하는사람 구독하는거 조아해요 마음찍는거 좋아하니까 귀찮으면 ...
# 7      자덕심함/  물여캐는 다 내 최애캐 / 요네즈켄시 앓아요 / 핑크샌즈, 이소솜, 남...
# 8      ᴀʟʟ ɪ ɴᴇᴇᴅ ɪs ʏᴏᴜ ʙᴀʙʏ ғᴜᴄᴋ ᴛʜᴇ ᴡᴏʀʟᴅ / FUB Fr...
# 9      rps❣ 헤어질땐 블언블 : 엑소 컴백으로 광명찾음...........💥스밍 합시다...
# 10
# 11                                                    미명
# 12     03 우울계 퀴어계 호모로맨틱 팬섹슈얼                      !¡¡...
# 13
# 14
# 15                                   연뮤새싹/2차덕/🍒여캐🍒/블언블자유
# 16                안녕하세요. 문선영이라고 합니다. 좋은 인연을 만들었으면 좋겠습니다.
# 17                    03년생 / 모든 혐오, 차별 반대 / G🌈\n인생목표 잠자기
# 18     엘소드합니다 레이븐 임모탈 좋아해요 거의 인게임에서 지냅니다             ...
# 19                   레식,몬헌,사퍼(가끔),옵치(가끔),롤(가끔),히오스(가아아끔)
# 20                    윤수니★ 방소단 주접러★ 언괄오류★ 맞괄 안돼있으면 뎀주세요!
# 21     아라시 메인으로 킹프리 섹시존 헤이세이점프도 파고 있습니다!!💙❤💚💛💜\n혹시 트친...
# 22                                        하이라이트 유선호 에이핑크
# 23                            하이큐. 잡덕러. 지뢰없는 청정 성인 올라운더.
# 24
# 25     롤쟁이 입니다! 취미로는 영상 만들고요 누구든 와서 말걸어 주시면 다가갑니다!! \...
# 26                                                    구독
# 27                   구독하게해주셔서 감사합니다. 저는 양심없이 음란한 걸 좋아합니다
# 28                                   이것저것.. 알뜰하게 결제하고 다님
# 29               JIN / BTS / 가끔 나눔도 해요 / 석진아, 내 행복은 너야 💜
# ...                                                  ...
# 48686                               滅後의 고통은 오로지 나의 몫이었다.
# 48687                                         솔로 가수 강다니엘
# 48688  최애는 강다니엘 차애는 윤지성 그리고 워너원 멤버 다좋아합니다 ㅎㅎㅎㅜㅡㅜ멤버들 한...
# 48689  *FUB FREE*\n20⬆️ 알림이 잘 안옵니다..                 ...
# 48690  20⬆ 💜大神 晃牙💜UNDEAD💜 드림러,\n코스프레, 잡덕, 당신이파는장르=내가파는장르
# 48691                                           잘생김에 취해라
# 48692  💜지금도 방탄 앞으로도 방탄 항상 보라해💜 2n살 꾹수니♡ | 모든 스루, 언팔 고...
# 48693
# 48694                       @B_hundred_Hyun @LAY_zhang 🍒
# 48695                              NAEIBIYO 내남자의이름은비스트요섭
# 48696  0n년생 잡덕/호칭:하랑 또는 동방의퇴마사/본진:신비아파트/부본진:앙상블스타즈/애니...
# 48697                                          야타에 미친 사람
# 48698  성인/취준생/🌱새싹(초보) 그림쟁이/BL GL HL/19금/욕트/일상/제랙님/오남/...
# 48699  사이다 | 42da | サイダ  ✧✦ʚ 歌ってみたɞ✦✧ GAME | 日本語OK   ...
# 48700                        맨날 후회하면서 감자튀김 8kg씩 사버리는 테러범
# 48701     HQ-!! / Free! / DRRR!! / 러브라이브 시리즈 / 자캐•커뮤•앤관켸
# 48702                    삼끼님 졸구탱 / 인장헤더 스샷 삼끼님💝 — 새싹 53일
# 48703  커뮤 계정입니다 정말....아무 것도 없는 계정... 앞으론 뭔가 있길 바랍니다.....
# 48704                                 03 여덕 | 여돌 최고 잡덕 뿅
# 48705               🌊언양🐋| 20🔼 | 커뮤러 | 쓰앵님 저랑 썰 풀어주셔야해요 |
# 48706  일요웹툰 둥굴레차! 버닝중! 가람이 앓다 죽을 청가람팡인^^ 건가람,가람른위주소비/...
# 48707                                             쟈근 연뮤덕
# 48708                                   🏆🏆이번 시즌 우승은 SK🏆🏆
# 48709  그림쟁이. 민국시대를 사는 캐릭터들을 그리고 씁니다. 청말민초, 동아시아 식민지·개...
# 48710                                                아마햄
# 48711                                   내가 이제 뭘 파는지 모르겠다
# 48712                                      성인 | 디키 | 드로저
# 48713  리버스 불가 주필×하필| 상시 트정                           ...
# 48714                                 굿즈팔이소녀,,, (거래계 아님)
# 48715                 ✨윤두준 용준형 양요섭 이기광 손동운 my HI5HLI5HT✨
#
#        user_followers_count  user_friends_count  \
# 0                        17                  39
# 1                       172                 273
# 2                         7                   7
# 3                       113                 109
# 4                       163                 513
# 5                       133                 133
# 6                        27                 101
# 7                       120                 154
# 8                       347                 329
# 9                        37                 551
# 10                       25                 117
# 11                       35                 270
# 12                       56                  56
# 13                        6                  37
# 14                        0                  84
# 15                      246                 519
# 16                     2243                2847
# 17                       23                 128
# 18                       76                 217
# 19                       83                 151
# 20                      786                1205
# 21                      186                 176
# 22                       43                 708
# 23                       22                 286
# 24                        0                  17
# 25                       39                  38
# 26                       81                2488
# 27                        5                1043
# 28                        4                 218
# 29                      115                  34
# ...                     ...                 ...
# 48686                    20                  20
# 48687                     7                 461
# 48688                    55                 181
# 48689                   388                 330
# 48690                   125                 138
# 48691                    67                  73
# 48692                   130                  85
# 48693                    32                 132
# 48694                   124                 782
# 48695                    12                 159
# 48696                   314                 808
# 48697                   157                 158
# 48698                    49                  53
# 48699                   166                 164
# 48700                    17                  27
# 48701                   147                 208
# 48702                    11                  10
# 48703                    81                  89
# 48704                    72                 167
# 48705                   139                 617
# 48706                   114                  98
# 48707                     3                  27
# 48708                   104                  93
# 48709                   632                 349
# 48710                    31                 118
# 48711                   168                  44
# 48712                   392                  99
# 48713                   153                 145
# 48714                    17                  57
# 48715                   153                 507
#
#                         user_location
# 0
# 1
# 2                                 원룸.
# 3                     🏠 HOUSE OF ARMY
# 4
# 5
# 6                               korea
# 7                               상어마음속
# 8           Welcome to my dream world
# 9                                찬백최애
# 10                              어딜까요?
# 11                                서부서
# 12                          이불 밑 침대 위
# 13
# 14
# 15                           침묵의별☍﹏⁰)
# 16
# 17               In Wonderland, E-E-E
# 18
# 19
# 20                 {애니멀즈},{병신즈},{팡만즈}
# 21                      쟈니스 내 통장 가져가시
# 22
# 23
# 24                            대한민국 부산
# 25
# 26                 인장 출처 - @peach_ohi
# 27              모든 글, 그림 항상 잘 보고있습니다
# 28
# 29
# ...                               ...
# 48686                       SH4M3L3SS
# 48687
# 48688
# 48689
# 48690
# 48691             에오르제아 안개빛마을 8구 46번지
# 48692  지뢰: 갠타잡,RPS,갠봇,잦은욕트,타팬덤(가수)욕 등
# 48693
# 48694                     김 새우 삶아먹는 중
# 48695
# 48696                  (주)감자연맹 소속 경호원
# 48697
# 48698                    코기는 고기가 먹고싶어
# 48699                         #오렌지멜로디
# 48700
# 48701
# 48702                메인트 새싹일기,언약식 모먼트
# 48703          인장 밤토님컴션 / 헤더는 랄프랑 미디✨
# 48704                      남돌 끌고오면 블블
# 48705                     (•ө•)♡ʕ•ﻌ•ʔ
# 48706                          중앙 마루밑
# 48707
# 48708
# 48709               산뜻하고 대담한 20c 동아시아
# 48710
# 48711
# 48712               인장은 팔삼달링/헤더는 지로달링
# 48713            甘棠遺愛| 9908875 70626
# 48714
# 48715                   두주니즈 _모든아이디통일
#
# [48716 rows x 14 columns]
